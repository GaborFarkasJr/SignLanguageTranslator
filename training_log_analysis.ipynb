# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("final_model/Resnet_3333_30fps_122res/log.csv")
df.plot(x="epoch", y=["train_acc", "eval_acc"])
plt.savefig("final_accuracy")
